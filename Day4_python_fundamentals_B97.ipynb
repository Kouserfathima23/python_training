# %%
    INTRODUCTION TO NUMBERS

# %%
num = 1
num1  = 2
type(num)
# Out:
# int

# %%
x=0.1
print(x)
# Out:
# 0.1

# %%
type(x) #decimal values in python
# Out:
# float

# %%
INTRODUCTION TO LIST DATATYPES:
A list is a collection of items  declared in quotes

HOW DO YOU DEFINE THE LIST?
ITS DENOTED IN [] #Square brackets

# %%
students = ['kouser','fathima','khatija','zainab','anaya','amiera','zuha','mariam']
print(students)
# Out:
# ['kouser', 'fathima', 'khatija', 'zainab', 'anaya', 'amiera', 'zuha', 'mariam']

# %%
print(students[1])
# Out:
# fathima

# %%
print(students[1].title())
# Out:
# Fathima

# %%
students.append('zohra') 
print(students)
 #NOTE: if you run the code of append more than once then it will add the name "zohra" that many times in the end
# Out:
# ['kouser', 'fathima', 'khatija', 'zainab', 'anaya', 'amiera', 'zuha', 'mariam', 'zohra', 'zohra']

# %%
students.append('zuha') #adding one more name
print(students)
# Out:
# ['kouser', 'fathima', 'khatija', 'zainab', 'anaya', 'amiera', 'zuha', 'mariam', 'zohra', 'zohra', 'zuha']

# %%
#requirement: add varun at 2nd index
students.insert(2,'varun')
print(students)
# Out:
# ['kouser', 'fathima', 'varun', 'khatija', 'zainab', 'anaya', 'amiera', 'zuha', 'mariam', 'zohra', 'zohra', 'zuha']

# %%
#req" modify varun name to saba
students[2]='saba'
print(students)
# Out:
# ['kouser', 'fathima', 'saba', 'khatija', 'zainab', 'anaya', 'amiera', 'zuha', 'mariam', 'zohra', 'zohra', 'zuha']

# %%
#req: delete the name kouser from the above list
TWO METHODS FOR DELETE 
1.pop() ---- temporary delete
2.del ---- permanent delete

# %%
x=students.pop()  #last name will be deleted 
print(students)
# Out:
# ['kouser', 'fathima', 'saba', 'khatija', 'zainab', 'anaya', 'amiera', 'zuha', 'mariam', 'zohra', 'zohra']

# %%
print(x)
# Out:
# zuha

# %%
a=students.pop(0) #first name will be deleted
print(students)
# Out:
# ['fathima', 'saba', 'khatija', 'zainab', 'anaya', 'amiera', 'zuha', 'mariam', 'zohra', 'zohra']

# %%
students1=['varun','akash','dev']
print(students1)
# Out:
# ['varun', 'akash', 'dev']

# %%
del students1[1]
print(students1)
# Out:
# ['varun', 'dev']
