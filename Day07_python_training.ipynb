# %%
INTRODUCTION TO DICTIONARIES 

how to define? ---> {}

# %%
#i want to  create a alien game 
alien = {'color':'green','points':5}
print(alien)
# Out:
# {'color': 'green', 'points': 5}

# %%
type(alien)
# Out:
# dict

# %%
#i want to add start position #adding new key value pairs in the dictionary
alien['start_position']='level1'
print(alien)
# Out:
# {'color': 'green', 'points': 5, 'start_position': 'level1'}

# %%
#how to acces new key value pairs
alien['color']
# Out:
# 'green'

# %%
alien['start_position']
# Out:
# 'level1'

# %%
alien['points']
# Out:
# 5

# %%
#to access give the key and get the value!

# %%
#create a new user account in instagram
user_account = {'username':'codetraining01','username':'code','dob':'01-01-2020','password':'548700'}
print(user_account)
# Out:
# {'username': 'code', 'dob': '01-01-2020', 'password': '548700'}

# %%
#to delete a key value pair 
del user_account['username']
print(user_account)
# Out:
# {'dob': '01-01-2020', 'password': '548700'}

# %%
print(alien)
# Out:
# {'color': 'green', 'points': 5, 'start_position': 'level1'}

# %%
NOTE : WE CANNOT GIVE VALUE AND GET THE KEY ,ONLY GIVING THE KEY AND GETTING THE VALUE IS POSSIBLE IF NOT ERROR WILL OCCUR

# %%
IMPLEMENTATION OF A FOR LOOP ON TOP OF A DICTIONARY

# %%
#general syntax of a dictionary
for tempvar01,tempvar02 in minvar.item():
    print(tempvar01)
    print(tempvar02)

# %%
print(alien)
# Out:
# {'color': 'green', 'points': 5, 'start_position': 'level1'}

# %%
for k,v in alien.items():
    print(k)
    print(v)
# Out:
# color
# green
# points
# 5
# start_position
# level1

# %%
for k,v in alien.items():
    print(f"key:{k}")
    print(f"vale:{v}")
# Out:
# key:color
# vale:green
# key:points
# vale:5
# key:start_position
# vale:level1

# %%
#give space
for k,v in alien.items():
    print(f"key:{k}")
    print(f"vale:{v}\n")
# Out:
# key:color
# vale:green
#
# key:points
# vale:5
#
# key:start_position
# vale:level1
