# %%
Continuation with string datatypes:
Introduction to f strings:

# %%
#general syntax for f strings
f"custom message,{place_holder-1} {place_holder-2}....{place_holdern}"

# %%
firstname= "kouser"
lastname= " fathima"
fullname=f"{firstname}{lastname}"
print(fullname)
# Out:
# kouser fathima

# %%
print(fullname.title())
# Out:
# Kouser Fathima

# %%
message = f"Good Job,{fullname.title()}"
print( message)
# Out:
# Good Job,Kouser Fathima

# %%
#Adding whitespaces to the strings
print("different colours:Red Black Pink Yellow Blue White Green Orange Golden Silver")
# Out:
# different colours:Red Black Pink Yellow Blue White Green Orange Golden Silver

# %%
#adding \n (new line delimeter)
print("different colours:\nRed\nBlack\nPink\nYellow\nBlue\nWhite\nGreen\nOrange\nGolden\nSilver")
# Out:
# different colours:
# Red
# Black
# Pink
# Yellow
# Blue
# White
# Green
# Orange
# Golden
# Silver

# %%
#adding \t (tab delimeter)
print("different colours:\n\tRed\n\tBlack\n\tPink\n\tYellow\n\tBlue\n\tWhite\n\tGreen\n\tOrange\n\tGolden\n\tSilver")
# Out:
# different colours:
# 	Red
# 	Black
# 	Pink
# 	Yellow
# 	Blue
# 	White
# 	Green
# 	Orange
# 	Golden
# 	Silver

# %%
#REMOVING WHITESPACES FROM THE STRING 
name = "    python"
print(name)
# Out:
#     python

# %%
name2 = "python    "
print(name2)
# Out:
# python

# %%
name.lstrip()
# Out:
# 'python'

# %%
name.rstrip()
# Out:
# '    python'

# %%
name3 = "   python   "
print(name3)
# Out:
#    python

# %%
name.strip()
# Out:
# 'python'

# %%
#zen of python:
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
