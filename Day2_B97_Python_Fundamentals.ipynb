# %%
#Variables in Python 
a=2
b=3

c=a+b
print(c)
# Out:
# 5

# %%
#Rules for declaring variables in Python
#RULE 1:No name spaces while declaring the variable
firstname = 'Kouser'
print(firstname)
# Out:
# Kouser

# %%
#RULE 2: variable name should not start with numbers 
Ex:
1firstname ='kouser'
print(1firstname)

# %%
#correct way
firstname = 'Kouser'
print(firstname)
# Out:
# Kouser

# %%
#RULE 3:A variable name should not contain any special character (@#$%*)
Ex:
name@ = 'kouser'
print(name@)

# %%
#correct way
name = 'kouser'
print(name)
# Out:
# kouser

# %%
#INTRODUCTION TO DATATYPES IN PYTHON
1.String (str)
2.Numbers-integers (int and float)
3.Lists (list)
4.Tuples (tuple)
5.Dictionaries (dict)

# %%
    #Introduction to string datatype(built functions)
type(name)
# Out:
# str

# %%
type(2)
# Out:
# int

# %%
#first letter of the names to be in capital
fullname = 'kouser fathima'
print(fullname.title())
# Out:
# Kouser Fathima

# %%
#entire name to be in capital
fullname = 'kouser fathima'
print(fullname.upper())
# Out:
# KOUSER FATHIMA

# %%
#entire name to be in smallcase letters
fullname = 'kouser fathima'
print(fullname.lower())
# Out:
# kouser fathima
